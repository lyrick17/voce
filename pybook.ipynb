# %%
import pandas as pd

defs = pd.read_csv('scripts/cleaned_def.csv')
pd.set_option('display.max_rows', None)
print(defs['POS'].value_counts())
# Out:
# POS
# ['n']                                                          84957
# ['a']                                                          35203
# ['v', 't']                                                     18217
# ['v', 'i']                                                      7168
# ['p', 'pr', '', 'vb', 'n']                                      5843
# ['imp', '', 'p', 'p']                                           5805
# ['adv']                                                         4485
# ['']                                                            3912
# ['pl', '']                                                      3440
# ['n', 'pl']                                                     1721
# ['superl']                                                      1314
# ['v']                                                            856
# ['v', 't', '', 'i']                                              476
# ['prep']                                                         314
# ...

# %% [markdown]
# # Premise
